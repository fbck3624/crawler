# %%
import requests 
# 引入函式庫
r = requests.get('https://github.com/timeline.json') 
# 想要爬資料的⽬目標網址
response = r.text 
# 模擬發送請求的動作
response
# Out:
# '{"message":"Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our blog post a couple of years back announcing that this API would go away: http://git.io/17AROg Fear not, you should be able to get what you need from the shiny new Events API instead.","documentation_url":"https://developer.github.com/v3/activity/events/#list-public-events"}'

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12427499552","type":"WatchEvent","actor":{"id":49215914,"login":"teenstitans","display_login":"teenstitans","gravatar_id":"","url":"https://api.github.com/users/teenstitans","avatar_url":"https://avatars.githubusercontent.com/u/49215914?"},"repo":{"id":8957185,"name":"forge/roaster","url":"https://api.github.com/repos/forge/roaster"},"payload":{"action":"started"},"public":true,"created_at":"2020-05-25T02:39:55Z","org":{"id":711249,"login":"forge","gravatar_id":"","url":"https://api.github.com/orgs/forge","avatar_url":"https://avatars.githubusercontent.com/u/711249?"}},{"id":"12427499551","type":"IssuesEvent","actor":{"id":37936606,"login":"github-learning-lab[bot]","display_login":"github-learning-lab","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab[bot]","avatar_url":"https://avatars.githubusercontent.com/u/37936606?"},"repo":{"id":266666942,"name":"LinberR/github-slideshow","url":"https://api.github.com/repos/LinberR/github-slideshow"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/LinberR/github-slideshow/issues/1","repository_url":"https://api.github.com/repos/LinberR/github-slideshow","labels_url":"https://api.github.com/repos/LinberR/github-slideshow/issues/1/labels{/name}","comments_url":"https://api.github.com/repos/LinberR/github-slideshow/issues/1/comments","events_url":"https://api.github.com/repos/LinberR/github-slideshow/issues/1/events","html_url":"https://github.com/LinberR/github-slideshow/issues/1","id":624008294,"node_id":"MDU6SXNzdWU2MjQwMDgyOTQ=","number":1,"title":"Getting Started with GitHub","user":{"login":"github-learning-lab[bot]","id":37936606,"node_id":"MDM6Qm90Mzc5MzY2MDY=","avatar_url":"https://avatars0.githubusercontent.com/in/10572?v=4","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab%5Bbot%5D","html_url":"https://github.com/apps/github-learning-lab","followers_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/followers","following_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/repos","events_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/received_events","type":"Bot","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2020-05-25T02:39:55Z","updated_at":"2020-05-25T02:39:55Z","closed_at":null,"author_association":"NONE","body":"# :wave: Welcome to GitHub Learning Lab\'s \\"Introduction to GitHub\\"\\n\\nTo get started, I’ll guide you through some important first steps in coding and collaborating on GitHub.\\n\\n:point_down: _This arrow means you can expand the window! Click on them throughout the course to find more information._\\n<details><summary>What is GitHub?</summary>\\n<hr>\\n\\n## What is GitHub?\\n\\nI\'m glad you asked! Many people come to GitHub because they want to contribute to open source <sup>[:book:](https://help.github.com/articles/github-glossary/#open-source)</sup> projects, or they\'re invited by teammates or classmates who use it for their projects. Why do people use GitHub for these projects?\\n\\n**At its heart, GitHub is a collaboration platform.**\\n\\nFrom software to legal documents, you can count on GitHub to help you do your best work with the collaboration and security tools your team needs. With GitHub, you can keep projects completely private, invite the world to collaborate, and streamline every step ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '12427499552',
#   'type': 'WatchEvent',
#   'actor': {'id': 49215914,
#    'login': 'teenstitans',
#    'display_login': 'teenstitans',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/teenstitans',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49215914?'},
#   'repo': {'id': 8957185,
#    'name': 'forge/roaster',
#    'url': 'https://api.github.com/repos/forge/roaster'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 711249,
#    'login': 'forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/711249?'}},
#  {'id': '12427499551',
#   'type': 'IssuesEvent',
#   'actor': {'id': 37936606,
#    'login': 'github-learning-lab[bot]',
#    'display_login': 'github-learning-lab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-learning-lab[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37936606?'},
#   'repo': {'id': 266666942,
#    'name': 'LinberR/github-slideshow',
#    'url': 'https://api.github.com/repos/LinberR/github-slideshow'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/LinberR/github-slideshow/issues/1',
#     'repository_url': 'https://api.github.com/repos/LinberR/github-slideshow',
#     'labels_url': 'https://api.github.com/repos/LinberR/github-slideshow/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/LinberR/github-slideshow/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/LinberR/github-slideshow/issues/1/events',
#     'html_url': 'https://github.com/LinberR/github-slideshow/issues/1',
#     'id': 624008294,
#     'node_id': 'MDU6SXNzdWU2MjQwMDgyOTQ=',
#     'number': 1,
#     'title': 'Getting Started with GitHub',
#     'user': {'login': 'github-learning-lab[bot]',
#      'id': 37936606,
#      'node_id': 'MDM6Qm90Mzc5MzY2MDY=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/10572?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-learning-lab',
#      'followers_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-05-25T02:39:55Z',
#     'updated_at': '2020-05-25T02:39:55Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '# :wave: Welcome to GitHub Learning Lab\'s "Introduction to GitHub"\n\nTo get started, I’ll guide you through some important first steps in coding and collaborating on GitHub.\n\n:point_down: _This arrow means you can expand the window! Click on them throughout the course to find more information._\n<details><summary>What is GitHub?</summary>\n<hr>\n\n## What is GitHub?\n\nI\'m glad you asked! Many people come to GitHub because they want to contribute to open source <sup>[:book:](https://help.github.com/articles/github-glossary/#open-source)</sup> projects, or they\'re invited by teammates or classmates who use it for their projects. Why do people use GitHub for these projects?\n\n**At its heart, GitHub is a collaboration platform.**\n\nFrom software to legal documents, you can count on GitHub to help you do your best work with the collaboration and security tools your team needs. With GitHub, you can keep projects completely private, invite the world to collaborate, and streamline every step of your project.\n\n**GitHub is also a powerful version control tool.**\n\nGitHub uses Git <sup>[:book:](https://help.github.com/articles/github-glossary/#git)</sup>, the most popular open source version control software, to track every contribution and contributor <sup>[:book:](https://help.github.com/articles/github-glossary/#contributor)</sup> to your project--so you know exactly where every line of code came from.\n\n**GitHub helps people do much more.**\n\nGitHub is used to build some of the most advanced technologies in the world. Whether you\'re visualizing data or building a new game, there\'s a whole community and set of tools on GitHub that can get you to the next step. This course starts with the basics, but we\'ll dig into the rest later!\n\n:tv: [Video: What is GitHub?](https://www.youtube.com/watch?v=w3jLJU7DT5E)\n<hr>\n</details><br>\n\n<details><summary>Exploring a GitHub repository</summary>\n<hr>\n\n## Exploring a GitHub repository\n\n:tv: [Video: Exploring a repository](https://www.youtube.com/watch?v=R8OAwrcMlRw)\n\n### More features\n\nThe video covered some of the most commonly-used features. Here are a few other items you can find in GitHub repositories:\n\n- Project boards: Create Kanban-style task tracking board within GitHub\n- Wiki: Create and store relevant project documentation\n- Insights: View a drop-down menu that contains links to analytics tools for your repository including:\n  - Pulse: Find information about the work that has been completed and the work that’s in-progress in this project dashboard\n  - Graphs: Graphs provide a more granular view of the repository activity including who contributed to the repository, who forked it, and when they completed the work\n\n### Special Files\n\nIn the video you learned about a special file called the README.md. Here are a few other special files you can add to your repositories:\n\n- CONTRIBUTING.md: The `CONTRIBUTING.md` is used to describe the process for contributing to the repository. A link to the `CONTRIBUTING.md` file is shown anytime someone creates a new issue or pull request.\n- ISSUE_TEMPLATE.md: The `ISSUE_TEMPLATE.md` is another file you can use to pre-populate the body of an issue. For example, if you always need the same types of information for bug reports, include it in the issue template, and every new issue will be opened with your recommended starter text.\n\n<hr>\n</details>\n\n### Using issues\n\nThis is an issue <sup>[:book:](https://help.github.com/articles/github-glossary/#issue)</sup>: a place where you can have conversations about bugs in your code, code review, and just about anything else.\n\nIssue titles are like email subject lines. They tell your collaborators what the issue is about at a glance. For example, the title of this issue is Getting Started with GitHub.\n\n\n<details><summary>Using GitHub Issues</summary>\n\n## Using GitHub issues\n\nIssues are used to discuss ideas, enhancements, tasks, and bugs. They mak ...
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z'},
#  {'id': '12427499544',
#   'type': 'WatchEvent',
#   'actor': {'id': 39040118,
#    'login': 'start-cat',
#    'display_login': 'start-cat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/start-cat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39040118?'},
#   'repo': {'id': 56305022,
#    'name': 'WhaleShark-Team/cobra',
#    'url': 'https://api.github.com/repos/WhaleShark-Team/cobra'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 37212104,
#    'login': 'WhaleShark-Team',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WhaleShark-Team',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37212104?'}},
#  {'id': '12427499547',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 3951023,
#    'login': 'ruuk',
#    'display_login': 'ruuk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ruuk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3951023?'},
#   'repo': {'id': 74621997,
#    'name': 'plexinc/plex-for-kodi',
#    'url': 'https://api.github.com/repos/plexinc/plex-for-kodi'},
#   'payload': {'action': 'closed',
#    'number': 297,
#    'pull_request': {'url': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297',
#     'id': 349056576,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5MDU2NTc2',
#     'html_url': 'https://github.com/plexinc/plex-for-kodi/pull/297',
#     'diff_url': 'https://github.com/plexinc/plex-for-kodi/pull/297.diff',
#     'patch_url': 'https://github.com/plexinc/plex-for-kodi/pull/297.patch',
#     'issue_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297',
#     'number': 297,
#     'state': 'closed',
#     'locked': False,
#     'title': 'playback speed',
#     'user': {'login': 'worldjoe',
#      'id': 876352,
#      'node_id': 'MDQ6VXNlcjg3NjM1Mg==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/876352?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/worldjoe',
#      'html_url': 'https://github.com/worldjoe',
#      'followers_url': 'https://api.github.com/users/worldjoe/followers',
#      'following_url': 'https://api.github.com/users/worldjoe/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/worldjoe/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/worldjoe/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/worldjoe/subscriptions',
#      'organizations_url': 'https://api.github.com/users/worldjoe/orgs',
#      'repos_url': 'https://api.github.com/users/worldjoe/repos',
#      'events_url': 'https://api.github.com/users/worldjoe/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/worldjoe/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "GHI (If applicable): #296\r\n\r\n## Description: Playback speed icons. These come from Kodi's confluence skin, which is GPL2. I believe @HitcherUK originally created most of these icons. I created (poorly) a few that were missing for speeds that I enjoy (up to 2.0).\r\n\r\n## Checklist:\r\n- [X] I have based this PR against the develop branch\r\n",
#     'created_at': '2019-12-04T19:33:31Z',
#     'updated_at': '2020-05-25T02:39:54Z',
#     'closed_at': '2020-05-25T02:39:54Z',
#     'merged_at': None,
#     'merge_commit_sha': 'deb0a040a5e4bd6d2e07ecd2b3a2461a953d95fe',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297/commits',
#     'review_comments_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297/comments',
#     'review_comment_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297/comments',
#     'statuses_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/statuses/2be21b5b5a8b0184ef9a311425d48dfaa9227062',
#     'head': {'label': 'worldjoe:develop',
#      'ref': 'develop',
#      'sha': '2be21b5b5a8b0184ef9a311425d48dfaa9227062',
#      'user': {'login': 'worldjoe',
#       'id': 876352,
#       'node_id': 'MDQ6VXNlcjg3NjM1Mg==',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/876352?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/worldjoe',
#       'html_url': 'https://github.com/worldjoe',
#       'followers_url': 'https://api.github.com/users/worldjoe/followers',
#       'following_url': 'https://api.github.com/users/worldjoe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/worldjoe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/worldjoe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/worldjoe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/worldjoe/orgs',
#       'repos_url': 'https://api.github.com/users/worldjoe/repos',
#       'events_url': 'https://api.github.com/users/worldjoe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/worldjoe/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 225940759,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU5NDA3NTk=',
#       'name': 'plex-for-kodi',
#       'full_name': 'worldjoe/plex-for-kodi',
#       'private': False,
#       'owner': {'login': 'worldjoe',
#        'id': 876352,
#        'node_id': 'MDQ6VXNlcjg3NjM1Mg==',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/876352?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/worldjoe',
#        'html_url': 'https://github.com/worldjoe',
#        'followers_url': 'https://api.github.com/users/worldjoe/followers',
#        'following_url': 'https://api.github.com/users/worldjoe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/worldjoe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/worldjoe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/worldjoe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/worldjoe/orgs',
#        'repos_url': 'https://api.github.com/users/worldjoe/repos',
#        'events_url': 'https://api.github.com/users/worldjoe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/worldjoe/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/worldjoe/plex-for-kodi',
#       'description': 'Offical Plex for Kodi add-on releases.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/worldjoe/plex-for-kodi',
#       'forks_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/forks',
#       'keys_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/teams',
#       'hooks_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/events',
#       'assignees_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/tags',
#       'blobs_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/languages',
#       'stargazers_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/subscription',
#       'commits_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/merges',
#       'archive_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/downloads',
#       'issues_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/worldjoe/plex-for-kodi/deployments',
#       'created_at': '2019-12-04T19:24:00Z',
#       'updated_at': '2019-12-04T19:24:02Z',
#       'pushed_at': '2019-12-04T19:28:20Z',
#       'git_url': 'git://github.com/worldjoe/plex-for-kodi.git',
#       'ssh_url': 'git@github.com:worldjoe/plex-for-kodi.git',
#       'clone_url': 'https://github.com/worldjoe/plex-for-kodi.git',
#       'svn_url': 'https://github.com/worldjoe/plex-for-kodi',
#       'homepage': None,
#       'size': 5503,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'gpl-2.0',
#        'name': 'GNU General Public License v2.0',
#        'spdx_id': 'GPL-2.0',
#        'url': 'https://api.github.com/licenses/gpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTg='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'plexinc:develop',
#      'ref': 'develop',
#      'sha': '14821daf75c1edcc5fd55f6c5492820a367ed5f1',
#      'user': {'login': 'plexinc',
#       'id': 324832,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyNDgzMg==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/324832?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/plexinc',
#       'html_url': 'https://github.com/plexinc',
#       'followers_url': 'https://api.github.com/users/plexinc/followers',
#       'following_url': 'https://api.github.com/users/plexinc/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/plexinc/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/plexinc/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/plexinc/subscriptions',
#       'organizations_url': 'https://api.github.com/users/plexinc/orgs',
#       'repos_url': 'https://api.github.com/users/plexinc/repos',
#       'events_url': 'https://api.github.com/users/plexinc/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/plexinc/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 74621997,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NDYyMTk5Nw==',
#       'name': 'plex-for-kodi',
#       'full_name': 'plexinc/plex-for-kodi',
#       'private': False,
#       'owner': {'login': 'plexinc',
#        'id': 324832,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyNDgzMg==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/324832?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/plexinc',
#        'html_url': 'https://github.com/plexinc',
#        'followers_url': 'https://api.github.com/users/plexinc/followers',
#        'following_url': 'https://api.github.com/users/plexinc/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/plexinc/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/plexinc/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/plexinc/subscriptions',
#        'organizations_url': 'https://api.github.com/users/plexinc/orgs',
#        'repos_url': 'https://api.github.com/users/plexinc/repos',
#        'events_url': 'https://api.github.com/users/plexinc/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/plexinc/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/plexinc/plex-for-kodi',
#       'description': 'Offical Plex for Kodi add-on releases.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/plexinc/plex-for-kodi',
#       'forks_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/forks',
#       'keys_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/teams',
#       'hooks_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/events',
#       'assignees_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/tags',
#       'blobs_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/languages',
#       'stargazers_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/subscription',
#       'commits_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/merges',
#       'archive_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/downloads',
#       'issues_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/deployments',
#       'created_at': '2016-11-23T23:31:28Z',
#       'updated_at': '2020-05-22T15:22:42Z',
#       'pushed_at': '2020-05-25T02:34:00Z',
#       'git_url': 'git://github.com/plexinc/plex-for-kodi.git',
#       'ssh_url': 'git@github.com:plexinc/plex-for-kodi.git',
#       'clone_url': 'https://github.com/plexinc/plex-for-kodi.git',
#       'svn_url': 'https://github.com/plexinc/plex-for-kodi',
#       'homepage': None,
#       'size': 5478,
#       'stargazers_count': 138,
#       'watchers_count': 138,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 83,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 112,
#       'license': {'key': 'gpl-2.0',
#        'name': 'GNU General Public License v2.0',
#        'spdx_id': 'GPL-2.0',
#        'url': 'https://api.github.com/licenses/gpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTg='},
#       'forks': 83,
#       'open_issues': 112,
#       'watchers': 138,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297'},
#      'html': {'href': 'https://github.com/plexinc/plex-for-kodi/pull/297'},
#      'issue': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297'},
#      'comments': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/plexinc/plex-for-kodi/statuses/2be21b5b5a8b0184ef9a311425d48dfaa9227062'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 2,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 226,
#     'deletions': 0,
#     'changed_files': 15}},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 324832,
#    'login': 'plexinc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/plexinc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/324832?'}},
#  {'id': '12427499542',
#   'type': 'CreateEvent',
#   'actor': {'id': 55655304,
#    'login': 'V1c4',
#    'display_login': 'V1c4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/V1c4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55655304?'},
#   'repo': {'id': 266666961,
#    'name': 'V1c4/MERN_app_Docker',
#    'url': 'https://api.github.com/repos/V1c4/MERN_app_Docker'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Un exercice de dockerisation',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z'},
#  {'id': '12427499537',
#   'type': 'WatchEvent',
#   'actor': {'id': 4238321,
#    'login': 'nash-ye',
#    'display_login': 'nash-ye',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nash-ye',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4238321?'},
#   'repo': {'id': 31352628,
#    'name': 'Freemius/wordpress-sdk',
#    'url': 'https://api.github.com/repos/Freemius/wordpress-sdk'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 11206613,
#    'login': 'Freemius',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Freemius',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11206613?'}},
#  {'id': '12427499543',
#   'type': 'WatchEvent',
#   'actor': {'id': 28798325,
#    'login': 'kikitian',
#    'display_login': 'kikitian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kikitian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28798325?'},
#   'repo': {'id': 264675954,
#    'name': 'dair-ai/ml-visuals',
#    'url': 'https://api.github.com/repos/dair-ai/ml-visuals'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 30384625,
#    'login': 'dair-ai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dair-ai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30384625?'}},
#  {'id': '12427499535',
#   'type': 'ForkEvent',
#   'actor': {'id': 35481233,
#    'login': 'chx33',
#    'display_login': 'chx33',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chx33',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35481233?'},
#   'repo': {'id': 111205328,
#    'name': '233boy/v2ray',
#    'url': 'https://api.github.com/repos/233boy/v2ray'},
#   'payload': {'forkee': {'id': 266666960,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNjY2NjY5NjA=',
#     'name': 'v2ray',
#     'full_name': 'chx33/v2ray',
#     'private': False,
#     'owner': {'login': 'chx33',
#      'id': 35481233,
#      'node_id': 'MDQ6VXNlcjM1NDgxMjMz',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/35481233?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chx33',
#      'html_url': 'https://github.com/chx33',
#      'followers_url': 'https://api.github.com/users/chx33/followers',
#      'following_url': 'https://api.github.com/users/chx33/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chx33/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chx33/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chx33/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chx33/orgs',
#      'repos_url': 'https://api.github.com/users/chx33/repos',
#      'events_url': 'https://api.github.com/users/chx33/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chx33/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/chx33/v2ray',
#     'description': '最好用的 V2Ray 一键安装脚本 & 管理脚本',
#     'fork': True,
#     'url': 'https://api.github.com/repos/chx33/v2ray',
#     'forks_url': 'https://api.github.com/repos/chx33/v2ray/forks',
#     'keys_url': 'https://api.github.com/repos/chx33/v2ray/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/chx33/v2ray/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/chx33/v2ray/teams',
#     'hooks_url': 'https://api.github.com/repos/chx33/v2ray/hooks',
#     'issue_events_url': 'https://api.github.com/repos/chx33/v2ray/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/chx33/v2ray/events',
#     'assignees_url': 'https://api.github.com/repos/chx33/v2ray/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/chx33/v2ray/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/chx33/v2ray/tags',
#     'blobs_url': 'https://api.github.com/repos/chx33/v2ray/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/chx33/v2ray/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/chx33/v2ray/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/chx33/v2ray/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/chx33/v2ray/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/chx33/v2ray/languages',
#     'stargazers_url': 'https://api.github.com/repos/chx33/v2ray/stargazers',
#     'contributors_url': 'https://api.github.com/repos/chx33/v2ray/contributors',
#     'subscribers_url': 'https://api.github.com/repos/chx33/v2ray/subscribers',
#     'subscription_url': 'https://api.github.com/repos/chx33/v2ray/subscription',
#     'commits_url': 'https://api.github.com/repos/chx33/v2ray/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/chx33/v2ray/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/chx33/v2ray/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/chx33/v2ray/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/chx33/v2ray/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/chx33/v2ray/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/chx33/v2ray/merges',
#     'archive_url': 'https://api.github.com/repos/chx33/v2ray/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/chx33/v2ray/downloads',
#     'issues_url': 'https://api.github.com/repos/chx33/v2ray/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/chx33/v2ray/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/chx33/v2ray/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/chx33/v2ray/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/chx33/v2ray/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/chx33/v2ray/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/chx33/v2ray/deployments',
#     'created_at': '2020-05-25T02:39:54Z',
#     'updated_at': '2020-05-25T02:39:50Z',
#     'pushed_at': '2020-04-18T02:03:47Z',
#     'git_url': 'git://github.com/chx33/v2ray.git',
#     'ssh_url': 'git@github.com:chx33/v2ray.git',
#     'clone_url': 'https://github.com/chx33/v2ray.git',
#     'svn_url': 'https://github.com/chx33/v2ray',
#     'homepage': '',
#     'size': 3638,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z'},
#  {'id': '12427499534',
#   'type': 'CreateEvent',
#   'actor': {'id': 18339873,
#    'login': 'victorfarruda',
#    'display_login': 'victorfarruda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/victorfarruda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18339873?'},
#   'repo': {'id': 258647763,
#    'name': 'victorfarruda/django-demo',
#    'url': 'https://api.github.com/repos/victorfarruda/django-demo'},
#   'payload': {'ref': 'pyup-update-sentry-sdk-0.14.3-to-0.14.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Algumas coisas que aprendi...',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z'},
#  {'id': '12427499533',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 159809315,
#    'name': 'geo6/api',
#    'url': 'https://api.github.com/repos/geo6/api'},
#   'payload': {'ref': 'dependabot/composer/develop/phpunit/phpunit-9.1.5',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 24525622,
#    'login': 'geo6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/geo6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24525622?'}},
#  {'id': '12427499530',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 192705648,
#    'name': 'mhaidarh/mhaidarhanif-web',
#    'url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/issues/58',
#     'repository_url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web',
#     'labels_url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/issues/58/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/issues/58/comments',
#     'events_url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/issues/58/events',
#     'html_url': 'https://github.com/mhaidarh/mhaidarhanif-web/pull/58',
#     'id': 622205661,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDIxMTE2ODE5',
#     'number': 58,
#     'title': 'Bump gatsby-plugin-offline from 3.2.1 to 3.2.6',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1756705059,
#       'node_id': 'MDU6TGFiZWwxNzU2NzA1MDU5',
#       'url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-05-21T02:41:58Z',
#     'updated_at': '2020-05-25T02:39:55Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/pulls/58',
#      'html_url': 'https://github.com/mhaidarh/mhaidarhanif-web/pull/58',
#      'diff_url': 'https://github.com/mhaidarh/mhaidarhanif-web/pull/58.diff',
#      'patch_url': 'https://github.com/mhaidarh/mhaidarhanif-web/pull/58.patch'},
#     'body': 'Bumps [gatsby-plugin-offline](https://github.com/gatsbyjs/gatsby/tree/HEAD/packages/gatsby-plugin-offline) from 3.2.1 to 3.2.6.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/gatsbyjs/gatsby/blob/master/packages/gatsby-plugin-offline/CHANGELOG.md">gatsby-plugin-offline\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/gatsbyjs/gatsby/compare/gatsby-plugin-offline@3.2.5...gatsby-plugin-offline@3.2.6">3.2.6</a> (2020-05-20)</h2>\n<p><strong>Note:</strong> Version bump only for package gatsby-plugin-offline</p>\n<h2><a href="https://github.com/gatsbyjs/gatsby/compare/gatsby-plugin-offline@3.2.4...gatsby-plugin-offline@3.2.5">3.2.5</a> (2020-05-20)</h2>\n<p><strong>Note:</strong> Version bump only for package gatsby-plugin-offline</p>\n<h2><a href="https://github.com/gatsbyjs/gatsby/compare/gatsby-plugin-offline@3.2.3...gatsby-plugin-offline@3.2.4">3.2.4</a> (2020-05-19)</h2>\n<p><strong>Note:</strong> Version bump only for package gatsby-plugin-offline</p>\n<h2><a href="https://github.com/gatsbyjs/gatsby/compare/gatsby-plugin-offline@3.2.2...gatsby-plugin-offline@3.2.3">3.2.3</a> (2020-05-18)</h2>\n<p><strong>Note:</strong> Version bump only for package gatsby-plugin-offline</p>\n<h2><a href="https://github.com/gatsbyjs/gatsby/compare/gatsby-plugin-offline@3.2.1...gatsby-plugin-offline@3.2.2">3.2.2</a> (2020-05-13)</h2>\n<p><strong>Note:</strong> Version bump only for package gatsby-plugin-offline</p>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/gatsbyjs/gatsby/commit/78271c317542bab22705508cf1d7bd4cfdb37200"><code>78271c3</code></a> chore(release): Publish</li>\n<li><a href="https://github.com/gatsbyjs/gatsby/commit/49133e2d8bdf81bedfca76c88e210afa82441490"><code>49133e2</code></a> chore(release): Publish</li>\n<li><a href="https://github.com/gatsbyjs/gatsby/commit/e393c89cf82db382a1f080c7a497536b06aef1da"><code>e393c89</code></a> chore(release): Publish</li>\n<li><a href="https://github.com/gatsbyjs/gatsby/commit/d19567d310d9cf92960a4b61e6d73c18146aa1d9"><code>d19567d</code></a> chore(release): Publish</li>\n<li><a href="https://github.com/gatsbyjs/gatsby/commit/0f53567b9a21f3c4284ff59e8c7316d9a4b1e0ea"><code>0f53567</code></a> chore(release): Publish</li>\n<li>See full diff in <a href="https://github.com/gatsbyjs/gatsby/commits/gatsby-plugin-offline@3.2.6/packages/gatsby-plugin-offline">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=gatsby-plugin-offline&package-manager=npm_and_yarn&previous-version=3.2.1&new-version=3.2.6)](https://dependabot.com/compatibility-score/?dependency-name=gatsby-plugin-offline&package-manager=npm_and_yarn&previous-version=3.2.1&new-version=3.2.6)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR o ...
#    'comment': {'url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/issues/comments/633348031',
#     'html_url': 'https://github.com/mhaidarh/mhaidarhanif-web/pull/58#issuecomment-633348031',
#     'issue_url': 'https://api.github.com/repos/mhaidarh/mhaidarhanif-web/issues/58',
#     'id': 633348031,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzMzM0ODAzMQ==',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-05-25T02:39:55Z',
#     'updated_at': '2020-05-25T02:39:55Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #63.'}},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z'},
#  {'id': '12427499527',
#   'type': 'PushEvent',
#   'actor': {'id': 59683,
#    'login': 'morozov',
#    'display_login': 'morozov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/morozov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59683?'},
#   'repo': {'id': 113793020,
#    'name': 'diff-sniffer/diff-sniffer',
#    'url': 'https://api.github.com/repos/diff-sniffer/diff-sniffer'},
#   'payload': {'push_id': 5122221831,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/appveyor-coverage',
#    'head': '35d2125278b04db854a5671e95344597b86d00f6',
#    'before': '50494457843fee142f9ad823ad6d3a5ff7914db9',
#    'commits': [{'sha': '35d2125278b04db854a5671e95344597b86d00f6',
#      'author': {'email': 'morozov@tut.by', 'name': 'Sergei Morozov'},
#      'message': 'Collect code coverage report from AppVeyor',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diff-sniffer/diff-sniffer/commits/35d2125278b04db854a5671e95344597b86d00f6'}]},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 34427538,
#    'login': 'diff-sniffer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/diff-sniffer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34427538?'}},
#  {'id': '12427499529',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 50992247,
#    'login': 'mousphere',
#    'display_login': 'mousphere',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mousphere',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50992247?'},
#   'repo': {'id': 200360385,
#    'name': 'mousphere/my_first_app',
#    'url': 'https://api.github.com/repos/mousphere/my_first_app'},
#   'payload': {'action': 'opened',
#    'number': 130,
#    'pull_request': {'url': 'https://api.github.com/repos/mousphere/my_first_app/pulls/130',
#     'id': 422515679,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDIyNTE1Njc5',
#     'html_url': 'https://github.com/mousphere/my_first_app/pull/130',
#     'diff_url': 'https://github.com/mousphere/my_first_app/pull/130.diff',
#     'patch_url': 'https://github.com/mousphere/my_first_app/pull/130.patch',
#     'issue_url': 'https://api.github.com/repos/mousphere/my_first_app/issues/130',
#     'number': 130,
#     'state': 'open',
#     'locked': False,
#     'title': 'Use volumes in docker',
#     'user': {'login': 'mousphere',
#      'id': 50992247,
#      'node_id': 'MDQ6VXNlcjUwOTkyMjQ3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/50992247?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mousphere',
#      'html_url': 'https://github.com/mousphere',
#      'followers_url': 'https://api.github.com/users/mousphere/followers',
#      'following_url': 'https://api.github.com/users/mousphere/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mousphere/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mousphere/starred{/owner}{/repo}',
# ...
#    'issue': {'url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297',
#     'repository_url': 'https://api.github.com/repos/plexinc/plex-for-kodi',
#     'labels_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297/comments',
#     'events_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297/events',
#     'html_url': 'https://github.com/plexinc/plex-for-kodi/pull/297',
#     'id': 532889360,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5MDU2NTc2',
#     'number': 297,
#     'title': 'playback speed',
#     'user': {'login': 'worldjoe',
#      'id': 876352,
#      'node_id': 'MDQ6VXNlcjg3NjM1Mg==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/876352?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/worldjoe',
#      'html_url': 'https://github.com/worldjoe',
#      'followers_url': 'https://api.github.com/users/worldjoe/followers',
#      'following_url': 'https://api.github.com/users/worldjoe/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/worldjoe/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/worldjoe/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/worldjoe/subscriptions',
#      'organizations_url': 'https://api.github.com/users/worldjoe/orgs',
#      'repos_url': 'https://api.github.com/users/worldjoe/repos',
#      'events_url': 'https://api.github.com/users/worldjoe/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/worldjoe/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-12-04T19:33:31Z',
#     'updated_at': '2020-05-25T02:39:54Z',
#     'closed_at': '2020-05-25T02:39:54Z',
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/plexinc/plex-for-kodi/pulls/297',
#      'html_url': 'https://github.com/plexinc/plex-for-kodi/pull/297',
#      'diff_url': 'https://github.com/plexinc/plex-for-kodi/pull/297.diff',
#      'patch_url': 'https://github.com/plexinc/plex-for-kodi/pull/297.patch'},
#     'body': "GHI (If applicable): #296\r\n\r\n## Description: Playback speed icons. These come from Kodi's confluence skin, which is GPL2. I believe @HitcherUK originally created most of these icons. I created (poorly) a few that were missing for speeds that I enjoy (up to 2.0).\r\n\r\n## Checklist:\r\n- [X] I have based this PR against the develop branch\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/comments/633348028',
#     'html_url': 'https://github.com/plexinc/plex-for-kodi/pull/297#issuecomment-633348028',
#     'issue_url': 'https://api.github.com/repos/plexinc/plex-for-kodi/issues/297',
#     'id': 633348028,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzMzM0ODAyOA==',
#     'user': {'login': 'ruuk',
#      'id': 3951023,
#      'node_id': 'MDQ6VXNlcjM5NTEwMjM=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/3951023?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ruuk',
#      'html_url': 'https://github.com/ruuk',
#      'followers_url': 'https://api.github.com/users/ruuk/followers',
#      'following_url': 'https://api.github.com/users/ruuk/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ruuk/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ruuk/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ruuk/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ruuk/orgs',
#      'repos_url': 'https://api.github.com/users/ruuk/repos',
#      'events_url': 'https://api.github.com/users/ruuk/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ruuk/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-25T02:39:54Z',
#     'updated_at': '2020-05-25T02:39:54Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "Thanks for the PR, but closing it as I've implemented it differently.\r\n\r\nI've added a simple text display under the current playback time, both to eliminate the need for images and increase in addon size, and to allow handling any speed without needing to add more images."}},
#   'public': True,
#   'created_at': '2020-05-25T02:39:55Z',
#   'org': {'id': 324832,
#    'login': 'plexinc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/plexinc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/324832?'}},
#  {'id': '12427499503',
#   'type': 'WatchEvent',
#   'actor': {'id': 13862075,
#    'login': 'gongsunqingyang',
#    'display_login': 'gongsunqingyang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gongsunqingyang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13862075?'},
#   'repo': {'id': 97844341,
#    'name': '12207480/TYCyclePagerView',
#    'url': 'https://api.github.com/repos/12207480/TYCyclePagerView'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'},
#  {'id': '12427499501',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 12380074,
#    'login': 'RubikZero',
#    'display_login': 'RubikZero',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RubikZero',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12380074?'},
#   'repo': {'id': 162215656,
#    'name': 'qicosmos/rest_rpc',
#    'url': 'https://api.github.com/repos/qicosmos/rest_rpc'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/qicosmos/rest_rpc/issues/11',
#     'repository_url': 'https://api.github.com/repos/qicosmos/rest_rpc',
#     'labels_url': 'https://api.github.com/repos/qicosmos/rest_rpc/issues/11/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/qicosmos/rest_rpc/issues/11/comments',
#     'events_url': 'https://api.github.com/repos/qicosmos/rest_rpc/issues/11/events',
#     'html_url': 'https://github.com/qicosmos/rest_rpc/issues/11',
#     'id': 624000451,
#     'node_id': 'MDU6SXNzdWU2MjQwMDA0NTE=',
#     'number': 11,
#     'title': '能否在类或结构体外使用MSGPACK_DEFINE',
#     'user': {'login': 'RubikZero',
#      'id': 12380074,
#      'node_id': 'MDQ6VXNlcjEyMzgwMDc0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/12380074?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/RubikZero',
#      'html_url': 'https://github.com/RubikZero',
#      'followers_url': 'https://api.github.com/users/RubikZero/followers',
#      'following_url': 'https://api.github.com/users/RubikZero/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/RubikZero/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/RubikZero/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/RubikZero/subscriptions',
#      'organizations_url': 'https://api.github.com/users/RubikZero/orgs',
#      'repos_url': 'https://api.github.com/users/RubikZero/repos',
#      'events_url': 'https://api.github.com/users/RubikZero/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/RubikZero/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-05-25T02:07:26Z',
#     'updated_at': '2020-05-25T02:39:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '例如，include的头文件中有需要传输的结构体，但是不希望修改头文件加入MSGPACK_DEFINE'},
#    'comment': {'url': 'https://api.github.com/repos/qicosmos/rest_rpc/issues/comments/633348029',
#     'html_url': 'https://github.com/qicosmos/rest_rpc/issues/11#issuecomment-633348029',
#     'issue_url': 'https://api.github.com/repos/qicosmos/rest_rpc/issues/11',
#     'id': 633348029,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzMzM0ODAyOQ==',
#     'user': {'login': 'RubikZero',
#      'id': 12380074,
#      'node_id': 'MDQ6VXNlcjEyMzgwMDc0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/12380074?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/RubikZero',
#      'html_url': 'https://github.com/RubikZero',
#      'followers_url': 'https://api.github.com/users/RubikZero/followers',
#      'following_url': 'https://api.github.com/users/RubikZero/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/RubikZero/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/RubikZero/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/RubikZero/subscriptions',
#      'organizations_url': 'https://api.github.com/users/RubikZero/orgs',
#      'repos_url': 'https://api.github.com/users/RubikZero/repos',
#      'events_url': 'https://api.github.com/users/RubikZero/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/RubikZero/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-25T02:39:54Z',
#     'updated_at': '2020-05-25T02:39:54Z',
#     'author_association': 'NONE',
#     'body': '> 你可以再建一个头文件，建一个一摸一样的结构体，传这个结构体，避免修改原有文件，需要一点适配的代码。\r\n\r\n感谢回复，这一点我也想到了，只是希望有更好的方法，如果可以的话希望能加入结构体外的定义宏，比如MSGPACK_DEFINE(MyStruct,MyStruct.a,MyStruct.b)这样'}},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'},
#  {'id': '12427499500',
#   'type': 'PushEvent',
#   'actor': {'id': 26160422,
#    'login': 'lpjune',
#    'display_login': 'lpjune',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lpjune',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26160422?'},
#   'repo': {'id': 264334203,
#    'name': 'lpjune/playlistener',
#    'url': 'https://api.github.com/repos/lpjune/playlistener'},
#   'payload': {'push_id': 5122221817,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5cf69ad4595c3c87b258d17b98e662b7c78b4de8',
#    'before': '20dcc2e968a69b0aef668857c000d155e629c556',
#    'commits': [{'sha': '5cf69ad4595c3c87b258d17b98e662b7c78b4de8',
#      'author': {'email': 'laurenporsini@gmail.com', 'name': 'lpjune'},
#      'message': 'clear button for searchbar',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lpjune/playlistener/commits/5cf69ad4595c3c87b258d17b98e662b7c78b4de8'}]},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'},
#  {'id': '12427499498',
#   'type': 'PushEvent',
#   'actor': {'id': 63286553,
#    'login': 'sixwudou',
#    'display_login': 'sixwudou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sixwudou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63286553?'},
#   'repo': {'id': 266666322,
#    'name': 'sixwudou/SF-',
#    'url': 'https://api.github.com/repos/sixwudou/SF-'},
#   'payload': {'push_id': 5122221815,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9b30fe4a84a572f3ac0a184028662b25eea7d81a',
#    'before': '0ac6d06e249def2e8640cf5fbed449eb8ba36bee',
#    'commits': [{'sha': '9b30fe4a84a572f3ac0a184028662b25eea7d81a',
#      'author': {'email': '63286553+sixwudou@users.noreply.github.com',
#       'name': 'sixwudou'},
#      'message': 'Create k倍区间',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sixwudou/SF-/commits/9b30fe4a84a572f3ac0a184028662b25eea7d81a'}]},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'},
#  {'id': '12427499493',
#   'type': 'PushEvent',
#   'actor': {'id': 32405058,
#    'login': 'zwh1666258377',
#    'display_login': 'zwh1666258377',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zwh1666258377',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32405058?'},
#   'repo': {'id': 257203468,
#    'name': 'zwh1666258377/gitbook2html',
#    'url': 'https://api.github.com/repos/zwh1666258377/gitbook2html'},
#   'payload': {'push_id': 5122221811,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e8c7cb72b1a515ad9f777923f399e9e00488d388',
#    'before': 'db35080973ee5b6623ad7b1d9b8480a02759ab9d',
#    'commits': [{'sha': 'e8c7cb72b1a515ad9f777923f399e9e00488d388',
#      'author': {'email': 'zhaodonghao586@outlook.com', 'name': 'doho'},
#      'message': '_',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zwh1666258377/gitbook2html/commits/e8c7cb72b1a515ad9f777923f399e9e00488d388'}]},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'},
#  {'id': '12427499491',
#   'type': 'CreateEvent',
#   'actor': {'id': 20056892,
#    'login': 'patchew-importer',
#    'display_login': 'patchew-importer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/patchew-importer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20056892?'},
#   'repo': {'id': 64726912,
#    'name': 'patchew-project/edk2',
#    'url': 'https://api.github.com/repos/patchew-project/edk2'},
#   'payload': {'ref': 'patchew/cover.1590373960.git.afish@apple.com',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'EDK II',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z',
#   'org': {'id': 19799179,
#    'login': 'patchew-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/patchew-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19799179?'}},
#  {'id': '12427499485',
#   'type': 'PushEvent',
#   'actor': {'id': 16741975,
#    'login': 'chendelin1982',
#    'display_login': 'chendelin1982',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chendelin1982',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16741975?'},
#   'repo': {'id': 203127079,
#    'name': 'Websoft9/ansible-neo4j',
#    'url': 'https://api.github.com/repos/Websoft9/ansible-neo4j'},
#   'payload': {'push_id': 5122221808,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd712f71c3cbc70a0feea07c517038fa86e5ef548',
#    'before': '9f5aa02c864d567e52e584a7aea3e33fad54b652',
#    'commits': [{'sha': 'd712f71c3cbc70a0feea07c517038fa86e5ef548',
#      'author': {'email': 'chendelin1982@126.com', 'name': 'chendelin1982'},
#      'message': 'Update neo4j.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Websoft9/ansible-neo4j/commits/d712f71c3cbc70a0feea07c517038fa86e5ef548'}]},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z',
#   'org': {'id': 36851177,
#    'login': 'Websoft9',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Websoft9',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36851177?'}},
#  {'id': '12427499482',
#   'type': 'WatchEvent',
#   'actor': {'id': 24651393,
#    'login': 'daydayRen',
#    'display_login': 'daydayRen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daydayRen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24651393?'},
#   'repo': {'id': 128398636,
#    'name': 'xingshaocheng/architect-awesome',
#    'url': 'https://api.github.com/repos/xingshaocheng/architect-awesome'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'},
#  {'id': '12427499480',
#   'type': 'PushEvent',
#   'actor': {'id': 56171954,
#    'login': 'httman',
#    'display_login': 'httman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/httman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56171954?'},
#   'repo': {'id': 212877752,
#    'name': 'httman/httmanbot1',
#    'url': 'https://api.github.com/repos/httman/httmanbot1'},
#   'payload': {'push_id': 5122221796,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '582d6db30fe47c9793d0510fb9a5732d97bbb2e6',
#    'before': '04961b87815540423e538530c99d45e4c9d305a1',
#    'commits': [{'sha': '582d6db30fe47c9793d0510fb9a5732d97bbb2e6',
#      'author': {'email': '56171954+httman@users.noreply.github.com',
#       'name': 'httman'},
#      'message': 'kill list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/httman/httmanbot1/commits/582d6db30fe47c9793d0510fb9a5732d97bbb2e6'}]},
#   'public': True,
#   'created_at': '2020-05-25T02:39:54Z'}]

# %%
import requests
import json

r = requests.get('https://cat-fact.herokuapp.com/facts')

if r.status_code == requests.codes.ok:
        print('ok')
       # print(r.status_code)
       # print(requests.codes.ok)
print(r.status_code) #伺服器回應的狀態碼
# Out:
# ok
# 200

# %%
json.loads(r.text)
# Out:
# {'all': [{'_id': '5887e1d85c873e0011036889',
#    'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '58e00b450aac31001185ed21',
#    'text': "There are 45 Hemingway cats living at the author's former home in Key West, Fla.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '58e00b970aac31001185edf9',
#    'text': 'A house cat is faster than Usain Bolt.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e00af60aac31001185ed1d',
#    'text': 'It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5e236d6bdc76630015d4c51f',
#    'type': 'cat',
#    'text': 'gato loves grace',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009550aac31001185ed12',
#    'text': 'The oldest cat video on YouTube dates back to 1894.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e008340aac31001185ecfb',
#    'text': 'Cats sleep 70% of their lives.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f87db9a11040c4a16343f',
#    'text': 'The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a000aac31001185ed15',
#    'text': 'Female cats are typically right-pawed while male cats are typically left-pawed.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a1a0aac31001185ed18',
#    'text': 'Cats and humans have nearly identical sections of the brain that control emotion.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e0088b0aac31001185ed09',
#    'text': "The world's largest cat measured 48.5 inches long.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00a7e0aac31001185ed19',
#    'text': "A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b1f0aac31001185ed1e',
#    'text': 'In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58f89cff11658e00113ddd26',
#    'text': 'Cats love to eat olives or for that matter anything preserved in brine.',
#    'type': 'cat',
#    'user': {'_id': '58f89c8d11658e00113ddd24',
#     'name': {'first': 'Malvika', 'last': 'Tewari'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
