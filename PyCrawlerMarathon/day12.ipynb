# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("https://www.ettoday.net/news/news-list.htm")
r.text
# Out:
# '<!doctype html>\r\n<html lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb" itemscope itemtype="http://schema.org/WebSite">\r\n<head>\r\n<meta charset="utf-8">\r\n<!-- ★★★以下非共用★★★ 開始 -->\r\n<meta name="robots" content="noarchive"/>\r\n<title>新聞總覽 | ETtoday新聞雲</title>\r\n<link rel="canonical" href="https://www.ettoday.net/news/news-list-2020-11-11-0.htm"/>\r\n\r\n<!-- 網頁社群分享meta 開始 -->\r\n<meta property="og:url" itemprop="url" content="https://www.ettoday.net/news/news-list-2020-11-11-0.htm"/>\r\n<meta property="og:title" itemprop="name" content="新聞總覽 | ETtoday新聞雲"/>\r\n<meta property="og:image" itemprop="image" content="https://cdn2.ettoday.net/style/ettoday2017/images/push.jpg"/>\r\n<meta property="og:image:width" content="1200"/>\r\n<meta property="og:image:height" content="628"/>\r\n<meta property="og:type" content="article"/>\r\n<meta name="description" content="ETtoday.net線上提供即時新聞，包括政治、財經、社會及國際要聞，以及生活、消費、寵物、新奇、娛樂、運動、旅遊資訊和相關新聞報導。" />\r\n<meta proper
# ...

# %%
soup=BeautifulSoup(r.text,"html5lib")
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebSite" lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb"><head>
# <meta charset="utf-8"/>
# <!-- ★★★以下非共用★★★ 開始 -->
# <meta content="noarchive" name="robots"/>
# <title>新聞總覽 | ETtoday新聞雲</title>
# <link href="https://www.ettoday.net/news/news-list-2020-11-11-0.htm" rel="canonical"/>
#
# <!-- 網頁社群分享meta 開始 -->
# <meta content="https://www.ettoday.net/news/news-list-2020-11-11-0.htm" itemprop="url" property="og:url"/>
# <meta content="新聞總覽 | ETtoday新聞雲" itemprop="name" property="og:title"/>
# <meta content="https://cdn2.ettoday.net/style/ettoday2017/images/push.jpg" itemprop="image" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="628" property="og:image:height"/>
# <meta content="article" property="og:type"/>
# <meta content="ETtoday.net線上提供即時新聞，包括政治、財經、社會及國際要聞，以及生活、消費、寵物、新奇、娛樂、運動、旅遊資訊和相關新聞報導。" name="description"/>
# ...

# %%
for d in soup.find(class_="part_list_2").find_all('h3'):
    print (d.text)
# Out:
# 2020/11/11 13:06健康醫過勞提離職要付「數百萬違約金」　民團籲政府正視不平等條款！
# 2020/11/11 13:05社會「親子鑑定P掉2字」兒子秒變別人的　台電員工逼妻一起驗下場出爐
# 2020/11/11 13:05ET車雲第一間放話要「純電化」的頂級車廠！賓利：品牌電動車2030年開賣
# 2020/11/11 13:04影劇邵雨薇甜認想婚「吳慷仁是真愛」：我們很適合！　決定復合關鍵曝光
# 2020/11/11 13:04體育日職／青木宣親成績、態度獲高層信賴　養樂多想再簽複數約
# 2020/11/11 13:04房產雲租屋PK員工宿舍！北漂哥吐「省7000元誘因」　內行：有錢才有底氣
# 2020/11/11 13:04房產雲萬坪綠海旁最低2字頭　新莊運動公園旁700萬築巢
# 2020/11/11 13:02大陸網購口紅送女友！到貨秒被罵「沒誠意」　他一怒竟揪出6億驚天巨案
# 2020/11/11 13:01大陸派出特殊軍機繞台　朱鳳蓮：解放軍行動是針對台獨的嚴正回應
# 2020/11/11 13:00國際美司法部起訴「台籍女子+2企業」　違反伊朗制裁令遭列黑名單
# 2020/11/11 12:59生活農委會110年「政策宣導」經費1774萬　陳吉仲：全數專項編列
# 2020/11/11 12:58社會苗栗娃娃車遭撞翻影像曝！路人踹破玻璃救3學童　圍成圈安慰送醫
# 2020/11/11 12:583C家電蘋果發表自主研發M1處理器　造就Mac大革命與App開發新變革
# 2020/11/11 12:56房產雲高雄家具一條街沒落！商家求重生　網紅直播、打卡景點通通來
# 2020/11/11 12:53國際美國兩黨互爭參議院掌控權　共和黨暫領先一席
# 2020/11/11 12:49體育復賽8連勝太陽積極網羅CP3　與雷霆洽談中！保羅曾誇鳳凰城主帥
# 2020/11/11 12:47財經鴻海MIH電動車開放平台大聯盟　攜手AWS實現「車聯網軟硬整合」
# 2020/11/11 12:47時尚BLACKPINK Jisoo韓國藝能界公認好人品！私服穿搭7範本超圈粉
# 2020/11/11 12:46生活台科大打造太陽風電系統監控實驗室　模擬業界環境、產學育才
# ...

# %%
res = {}

for d in soup.find(class_="part_list_2").find_all('h3'):
    date = d.find(class_="date").text
    title = d.find('a').text
    tag = d.find(class_='tag').text
#    tag = d.select('.tag')[0].text
    res.setdefault(tag, [])
    #dict.setdefault(key, default=None)，如果鍵不存在於字典中，將會添加該鍵並將default的值設為該鍵的默認值，
    #如果鍵存在於字典中，將讀出該鍵原來對應的值，default的值不會覆蓋原來已經存在的鍵的值。
    res[tag].append({ #append() 方法用于在列表末尾添加新的对象。
        'title': title,
        'date': date
    })
    
print(res)
# Out:
# {'大陸': [{'title': '港版國安法前夕！\u3000香港「多區衝突」360名示威者被逮捕', 'date': '2020/05/28 10:08'}, {'title': '「逃犯條例」後港人來台即飆升\u3000移民署：彰顯對我國信任', 'date': '2020/05/28 09:59'}, {'title': '遭示威者圍毆血流滿面！港律師回憶「那一刻極度恐懼」：差點命都沒了', 'date': '2020/05/28 09:31'}, {'title': '陸委會公布「香港人道救援」四大原則\u3000將編列預算', 'date': '2020/05/28 09:09'}, {'title': '港版國安法／北京大逆襲\u3000港社運人士措手不及...喊繼續抗爭下去', 'date': '2020/05/28 09:05'}, {'title': '港版國安法／全國人大今投票表決\u3000最快8月完成立法實施', 'date': '2020/05/28 06:30'}, {'title': '港版國安法／「反修例」抗爭將滿周年\u3000北京從挺林鄭到鐵腕介入', 'date': '2020/05/28 06:30'}, {'title': '港版國安法／港人憂經濟衝擊「好怕走進死胡同」：大家都跑不掉', 'date': '2020/05/28 06:30'}], '生活': [{'title': '觀光大家長被忽視？陳時中全台跑透透「不揪林佳龍」\u3000藍委酸：同床異夢', 'date': '2020/05/28 10:07'}, {'title': '「甩飲料1星輾壓」卡卡兒869字槓上咖啡店\u3000批「影片斷章取義」：我就是蠢\u3000', 'date': '2020/05/28 10:00'}, {'title': '文華東方大量解僱！林佳龍曝：他們「沒來申請紓困金」', 'date': '2020/05/28 09:12'}, {'title': '海戰車老闆很想哭！\u3000還原「2隻4140元」真相遭酸：破店不適合賣高檔海鮮', 'date': '2020/05/28 09:08'}, {'title': '快訊／豪雨炸高雄！高雄三國通道草衙、金福路口積水\u3000北上匝道封閉', 'date': '202
# ...

# %%
# ③ 哪一個類別的文章最多
data = []
for i in res:
    print(i, len(res[i]))
    d = {}
    d['tag'] = i
    d['count'] = len(res[i])
    data.append(d)

for d in sorted(data, key=lambda d: d['count'])[::-1]:
    print(d)
# Out:
# 政治 7
# 影劇 14
# 房產雲 4
# 地方 1
# 社會 12
# 生活 16
# 大陸 5
# 財經 4
# ET車雲 2
# 旅遊 2
# 時尚 4
# 名家 1
# 國際 16
# 探索 2
# 論壇 1
# 網搜 2
# 體育 5
# 軍武 1
# 消費 1
# {'tag': '國際', 'count': 16}
# {'tag': '生活', 'count': 16}
# {'tag': '影劇', 'count': 14}
# {'tag': '社會', 'count': 12}
# {'tag': '政治', 'count': 7}
# {'tag': '體育', 'count': 5}
# {'tag': '大陸', 'count': 5}
# {'tag': '時尚', 'count': 4}
# {'tag': '財經', 'count': 4}
# {'tag': '房產雲', 'count': 4}
# {'tag': '網搜', 'count': 2}
# {'tag': '探索', 'count': 2}
# {'tag': '旅遊', 'count': 2}
# {'tag': 'ET車雲', 'count': 2}
# {'tag': '消費', 'count': 1}
# {'tag': '軍武', 'count': 1}
# {'tag': '論壇', 'count': 1}
# {'tag': '名家', 'count': 1}
# {'tag': '地方', 'count': 1}
